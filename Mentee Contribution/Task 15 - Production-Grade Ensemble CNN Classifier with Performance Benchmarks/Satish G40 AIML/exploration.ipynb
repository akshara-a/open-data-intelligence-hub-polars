# %% [markdown]
# # CIFAR-10 CNN Ensemble Exploration
#
# This notebook outlines the model training workflow, evaluation strategy, and deployment analysis for the ensemble CNN classifier.

# %%
import os
from pathlib import Path

project_root = Path.cwd().resolve()
print(project_root)
print('Project ready for CIFAR-10 training and ensemble benchmarking.')
